# %% [markdown]
# #### Задание 1

# %% [markdown]
# $7 \cdot \begin{bmatrix}
#        5 & 10   \\
#        7 & 12   \\
#        11.3 & 5 \\
#        25 &  30
#     \end{bmatrix}+
#  2 \cdot \begin{bmatrix}
#        5 & 10   \\
#        7 & 12   \\
#        11.3 & 5 \\
#        25 &  30
#     \end{bmatrix}$ =
#      $9 \cdot \begin{bmatrix}
#        5 & 10   \\
#        7 & 12   \\
#        11.3 & 5 \\
#        25 &  30
#     \end{bmatrix}$ =
#      $\begin{bmatrix}
#        45 & 90   \\
#        63 & 108   \\
#        101.7 & 45 \\
#        225 &  270
#     \end{bmatrix}$

# %% [markdown]
# #### Задание 2

# %% [markdown]
# $ \begin{cases}
#     3x - 2y + 5z = 7\\
#     7x + 4y - 8z = 3\\
#     5x - 3y - 4z = -12
#   \end{cases}
# $

# %% [markdown]
# Выразим $y$ из первого уравнения

# %% [markdown]
# $y = 1.5x + 2.5z - 3.5$

# %% [markdown]
# $7x + 4(1.5x+2.5z−3.5) -8z = 3$

# %% [markdown]
# $7x + 6x + 10z − 14 - 8z = 3$

# %% [markdown]
# $13x + 2z = 17$

# %% [markdown]
# $z = 8.5-6.5x$

# %% [markdown]
# $5x - 3 (1.5x + 2.5(8.5-6.5x)-3.5)-4(8.5-6.5x)=-12$

# %% [markdown]
# $5x - 4.5x - 63.75 + 48.75x + 10.5-34 + 26x=-12$

# %% [markdown]
# $75.25x = 75.25$

# %% [markdown]
# $x = 1 \quad z = 2 \quad y = 3$

# %% [markdown]
# Каждое уравнение линейно, следовательно система линейна

# %% [markdown]
# #### Задание 3

# %% [markdown]
# $ \begin{cases}
#     x^2 + yx -9 = 0\\
#     x - \frac{y}{5} = 0
#   \end{cases}
# $

# %% [markdown]
# $ \begin{cases}
#     x^2 + yx -9 = 0\\
#     y = 5x
#   \end{cases}
# $

# %% [markdown]
# $6x^2 -9 = 0$

# %% [markdown]
# $x^2 = \frac{3}{2}$

# %% [markdown]
# $x = \pm\sqrt{\frac{3}{2}}$

# %% [markdown]
# $\begin{cases}
# x = \sqrt{\frac{3}{2}} \quad y = 5\sqrt{\frac{3}{2}} \\
# x = -\sqrt{\frac{3}{2}} \quad y = -5\sqrt{\frac{3}{2}}
# \end{cases}$

# %% [markdown]
# Первое уравнение квадратичное, следователдьно система уравнений нелинейна

# %% [markdown]
# #### Задание 4
# Решите задачу:
# Площадь пола прямоугольной комнаты равна 48 м2,а его периметр равен 28 м. Найдите длину и ширину комнаты.

# %% [markdown]
# $ \begin{cases}
#     xy = 48\\
#     2(x+y) = 28
#   \end{cases}
# $

# %% [markdown]
# $ \begin{cases}
#     y = 48/x\\
#     x = 14 - y
#   \end{cases}
# $

# %% [markdown]
# $x = 14 - 48/x$

# %% [markdown]
# $x^2 - 14x + 48 = 0$

# %% [markdown]
# $x_1 = 8 \quad x_2 = 6$

# %% [markdown]
# $x = 8 \quad y = 6$

# %% [markdown]
# #### Задание 4

# %% [markdown]
# Постройте на одном графике две кривые y(x) для функции двух переменной y(k,x)=cos(k∙x), взяв для одной кривой значение k=1, а для другой – любое другое k, не равное 1.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
x = np.linspace(-np.pi, np.pi, 1000)
k = 3
y = np.cos(x)
y_1 = np.cos(x * k)

plt.title(f'cos(x) & cos({k}x)'cos(alf))
plt.xlabel('x')
plt.ylabel('y')

plt.plot(x ,y)
plt.plot(x ,y_1)
plt.show()
